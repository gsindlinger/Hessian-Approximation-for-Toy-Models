# %% [markdown]
# # Hessian Approximation for Toy Models
#
# The idea behind this notebook is to compare the implementations of the various approximations and keep track of all of the results.
#
# In the first part, several sanity checks are performed, which serve to provide a better understanding of the relationships and to ensure the correctness of the code.
#
# The second part then delves deeper into the context and presents different results.

# %%
# %load_ext autoreload

# %% [markdown]
# ## Sanity Checks

# %% [markdown]
# ### 1. Linear Regression with 1-D Output for Random Dataset
# **Main goal**: Comparing the sklearn regression setup with the JAX Setup

# %%
from config.config import (
    Config,
    ModelConfig,
    RandomRegressionConfig,
    TrainingConfig,
    TrainingConfig,
    get_config,
)
from models.train import train_or_load


# config = get_config("random_regression_single_feature")
config = Config(
    dataset=RandomRegressionConfig(
        n_samples=1000,
        n_features=1,
        n_targets=1,
        noise=10,
        random_state=42,
        train_test_split=1,
    ),
    model=ModelConfig(name="linear", loss="mse"),
    training=TrainingConfig(
        epochs=100,
        lr=0.01,
        optimizer="sgd",
        batch_size=100,
        loss="mse",
    ),
)
model, dataset, params, loss = train_or_load(config)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 169.17it/s]

# %%
## Plot results
import matplotlib.pyplot as plt
import numpy as np
import jax.numpy as jnp
from jax import random

x, y = dataset.get_train_data()
x_test = jnp.linspace(jnp.min(x), jnp.max(x), 100).reshape(-1, 1)
y_pred = model.apply(params, x_test)
plt.scatter(x, y, label="Train data")

# make regression line red
plt.plot(x_test, y_pred, color="red", label="Regression line")
plt.legend()
plt.show()

# %%
### Compare with sklearn

from sklearn.linear_model import LinearRegression

sk_model = LinearRegression()
sk_model.fit(np.array(x), np.array(y))
y_sk_pred = sk_model.predict(np.array(x_test))
plt.scatter(x, y, label="Train data")
plt.plot(
    x_test, y_sk_pred, color="green", linestyle="--", label="SKlearn Regression line"
)
plt.plot(x_test, y_pred, color="red", linestyle="--", label="JAX Regression line")
plt.legend()
plt.show()

## Calculate MSE for both models
# The MSE should be very small, close to 0
from sklearn.metrics import mean_squared_error

mse_jax = mean_squared_error(np.array(y_pred), np.array(y_sk_pred))
print(f"MSE between JAX and SKlearn predictions: {mse_jax}")
# Out:
# MSE between JAX and SKlearn predictions: 0.017557382583618164

# %% [markdown]
# ### 2. Linear Regression on Energy Dataset
#
# **Main goal:** Verify correctness of implementation by comparing the trained regression setting with (exact) sklearn regression implementation, then moving on to the hessian.
#
# For the hessian, we first introduce some notation:
# - $H = $ Hessian of a model which is generated by double differentiation using JAX $\texttt{hessian}$ function
# - $H_{\text{exact}} = $ Hessian which is computed by some exact formula (only applicable for linear model setting, i.e., linear regression, linear classification)
# - $H_{\text{GNH}} = $ Gauss-Newton Hessian ($J^T_{\theta} H_{\text{output}} J_{\theta}$) computed by using JAX differentiation tools
#
# For the Hessian in the regression setting it yields:
# $$ H = H_{GNH} $$
#
# So in the linear setting want to observe that
# $$ || H_{\text{exact}} - H_{GNH} || \approx || H_{\text{exact}} - H || \approx 0 $$
#
# Furthermore, we are interested in the connection of the Fisher information matrix $ F(\theta \mid X)$ to the Hessian. Based on calculus it should hold:
# $$ F(\theta \mid X) = \frac{1}{\sigma^2} X^\top X = \frac{\sigma^2}{2} H$$

# %%
from config.config import LinearModelConfig, UCIDatasetConfig, get_config


# config = get_config("energy")
config = Config(
    dataset=UCIDatasetConfig(
        train_test_split=1,
    ),
    model=LinearModelConfig(loss="mse", hidden_dim=[]),
    training=TrainingConfig(
        epochs=200,
        lr=0.01,
        batch_size=768,
        optimizer="adam",
        loss="mse",
    ),
)
model_2, dataset_2, params_2, loss_2 = train_or_load(config)
# Out:
# 100%|██████████| 200/200 [00:00<00:00, 229.71it/s]

# %%
## Compare with sklearn
x, y = dataset_2.get_train_data()
y_pred = model_2.apply(params_2, x)

from sklearn.linear_model import LinearRegression

sk_model = LinearRegression()
sk_model.fit(np.array(x), np.array(y))
sk_predictions = sk_model.predict(np.array(x))

## Calculate MSE for both models
# Distance should be very small
from sklearn.metrics import mean_squared_error

mse_jax = mean_squared_error(np.array(y_pred), np.array(sk_predictions))
print(f"MSE between JAX and SKlearn predictions: {mse_jax}")
# Out:
# MSE between JAX and SKlearn predictions: 0.00020859498181380332

# %% [markdown]
# #### Hessian Comparison

# %%
# config = get_config("energy")
config_2 = Config(
    dataset=UCIDatasetConfig(
        train_test_split=1,
    ),
    model=LinearModelConfig(loss="mse", hidden_dim=[]),
    training=TrainingConfig(
        epochs=200,
        lr=0.01,
        batch_size=768,
        optimizer="adam",
        loss="mse",
    ),
)
model_2, dataset_2, params_2, loss_2 = train_or_load(config_2)

config_3 = Config(
    dataset=RandomRegressionConfig(
        n_samples=1000,
        n_features=100,
        n_targets=10,
        noise=20,
        random_state=42,
        train_test_split=1,
    ),
    model=LinearModelConfig(loss="mse", hidden_dim=[]),
    training=TrainingConfig(
        epochs=200,
        lr=0.001,
        batch_size=100,
        optimizer="sgd",
        loss="mse",
    ),
)
model_3, dataset_3, params_3, loss_3 = train_or_load(config_3)
# Out:
# 100%|██████████| 200/200 [00:00<00:00, 232.85it/s]

# %%
from typing import Any
from data.data import AbstractDataset
from hessian_approximations.gauss_newton.gauss_newton import GaussNewton
from hessian_approximations.hessian.exact_hessian_regression import (
    HessianExactRegression,
)
from hessian_approximations.hessian.hessian import Hessian
from hessian_approximations.hessian_approximations import HessianApproximation
from models.train import ApproximationModel, get_loss_fn


def compare_hessians(
    model: ApproximationModel, params: Any, dataset: AbstractDataset, config: Config
):
    exact_hessian_regression = {
        "name": "exact-hessian-regression",
        "create": HessianExactRegression(full_config=config),
    }
    hessian = {"name": "hessian", "create": Hessian(full_config=config)}
    gauss_newton = {
        "name": "gauss-newton",
        "create": GaussNewton(full_config=config),
    }

    hessian_approximations = [exact_hessian_regression, hessian, gauss_newton]
    hessian_results = {}

    for hessian_approx in hessian_approximations:
        method: HessianApproximation = hessian_approx["create"]
        hessian_matrix = method.compute_hessian()
        hessian_results[hessian_approx["name"]] = hessian_matrix

    # Compare the Hessian matrices
    for i in range(len(hessian_results)):
        for j in range(i + 1, len(hessian_results)):
            i_name = hessian_approximations[i]["name"]
            j_name = hessian_approximations[j]["name"]
            i_matrix = hessian_results[i_name]
            j_matrix = hessian_results[j_name]
            matrix_diff = i_matrix - j_matrix
            diff = jnp.linalg.norm(matrix_diff, "fro")
            print(
                f"Difference between {i_name} and {j_name} for Frobenius norm: {diff}"
            )

    print("----")
    # Search for max different entries
    for i in range(len(hessian_results)):
        for j in range(i + 1, len(hessian_results)):
            i_name = hessian_approximations[i]["name"]
            j_name = hessian_approximations[j]["name"]
            matrix_diff = hessian_results[i_name] - hessian_results[j_name]

            max_diff = jnp.max(jnp.abs(matrix_diff))
            print(f"Max absolute difference between {i_name} and {j_name}: {max_diff}")


print("Results for Energy dataset:")
compare_hessians(model_2, params_2, dataset_2, config_2)
print("======")
print("Results for Random Regression dataset:")
compare_hessians(model_3, params_3, dataset_3, config_3)
# Out:
# Results for Energy dataset:
# Difference between exact-hessian-regression and hessian for Frobenius norm: 7.288075644954694e-06
# Difference between exact-hessian-regression and gauss-newton for Frobenius norm: 4.891482708761623e-06
# Difference between hessian and gauss-newton for Frobenius norm: 5.463207799039083e-06
# ----
# Max absolute difference between exact-hessian-regression and hessian: 2.5033950805664062e-06
# Max absolute difference between exact-hessian-regression and gauss-newton: 2.086162567138672e-06
# Max absolute difference between hessian and gauss-newton: 2.0265579223632812e-06
# ======
# Results for Random Regression dataset:
# Difference between exact-hessian-regression and hessian for Frobenius norm: 2.36254007649297e-06
# Difference between exact-hessian-regression and gauss-newton for Frobenius norm: 2.5062224105531273e-06
# Difference between hessian and gauss-newton for Frobenius norm: 2.3904292447696207e-06
# ----
# Max absolute difference between exact-hessian-regression and hessian: 4.76837158203125e-07
# Max absolute difference between exact-hessian-regression and gauss-newton: 4.76837158203125e-07
# Max absolute difference between hessian and gauss-newton: 7.152557373046875e-07

# %% [markdown]
# #### FIM vs. Hessian
#
# Note, that this comparison calculates the empirical FIM to be able to compare the true Hessian with the FIM implementation. The equality holds for the 'true' FIM only when the loss of the trained model is minimized.
#
# Remember, when setting $\sigma^2 = 1$, we want to observe:
# $$ F(\theta \mid X) = \frac{1}{2} H$$

# %%
from hessian_approximations.fim.fisher_information import FisherInformation


hessian = {"name": "hessian", "create": Hessian(full_config=config_3)}
fim = {"name": "fim", "create": FisherInformation(full_config=config_3)}

hessian_approximations = [hessian, fim]
hessian_results = {}

for hessian_approx in hessian_approximations:
    method: HessianApproximation = hessian_approx["create"]
    hessian_matrix = method.compute_hessian()

    hessian_results[hessian_approx["name"]] = hessian_matrix

# Compare the Hessian matrices
hessian_matrix = hessian_results["hessian"]
fim_matrix = hessian_results["fim"]

# Check, that FIM is approximately half of the Hessian for regression with MSE loss
matrix_diff = hessian_matrix - 2 * fim_matrix
diff = jnp.linalg.norm(matrix_diff, "fro")
print(f"Difference between hessian and fim for Frobenius norm: {diff}")
# Out:
# Difference between hessian and fim for Frobenius norm: 2.5554636522429064e-06

# %% [markdown]
# ### 3. E-KFAC
#
# First we want to verify that our implementation is correct. We're doing that by comparing the computed covariances with the gradient of the logits of each layer. We define
# $$
# s_l = \nabla_{W_l a_{l-1}} \log p(y \mid x; \theta)
# $$
# as the preactivation gradients of a single layer and
# $$
# a_l = \phi(W_l a_{l-1})
# $$
# as the activations of layer $l$.
#
# Then KFAC approximates the Gauss-Newton Hessian by a block-diagonal structure, leaving every block $\mathbb{G}_l$ independent, and each $\mathbb{G}_l$ is defined as:
# $$
# \mathbb{G}_l \approx \mathbb{E}[a_{l-1} a_{l-1}^T] \otimes \mathbb{E}[s_l s_l^T]
# $$
#
# Based on the derivation of KFAC it should hold:
# $$
# \begin{align}
# \nabla_{W_l} \log p(y \mid x; \theta)
# &= \nabla_{W_l a_{l-1}} \log p(y \mid x; \theta) \, a_{l-1}^\top \\
# &= s_l \, a_{l-1}^\top
# \end{align}
# $$
#
# That's what we want to verify first!

# %%
import jax
from config.config import RandomClassificationConfig
from config.hessian_approximation_config import KFACRunConfig
from hessian_approximations.kfac.kfac import KFAC


config_ekfac = Config(
    dataset=RandomClassificationConfig(
        n_samples=1000,
        n_features=20,
        n_informative=10,
        n_classes=3,
        random_state=42,
        train_test_split=1,
    ),
    model=LinearModelConfig(loss="cross_entropy", hidden_dim=[10, 5]),
    training=TrainingConfig(
        epochs=100,
        lr=0.001,
        optimizer="sgd",
        loss="cross_entropy",
    ),
)

model_ekfac, dataset_ekfac, params_ekfac, loss_ekfac = train_or_load(config_ekfac)
training_data, training_targets = dataset_ekfac.get_train_data()
kfac_approx = KFAC.setup_with_run_and_build_config(
    full_config=config_ekfac, run_config=KFACRunConfig(recalc_kfac_components=True)
)
kfac_approx.compute_hessian()


def normal_loss_fn(params, x, y, model):
    """Standard loss function without KFAC wrapper."""
    pred = model.apply(params, x)
    return get_loss_fn(config_ekfac.model.loss)(pred, y, reduction="sum")


ground_truth_grads = jax.grad(normal_loss_fn)(
    params_ekfac, training_data, training_targets, model_ekfac
)

for key in ground_truth_grads["params"].keys():
    true_grad = ground_truth_grads["params"][key]["kernel"]

    a = kfac_approx.collector.captured_data[key][0]
    g = kfac_approx.collector.captured_data[key][1]

    ag = jnp.einsum("ni,nj->ij", a, g)

    # Find max absolute difference
    max_diff = jnp.max(jnp.abs(ag - true_grad))
    print(f"Max absolute difference for {key}: {max_diff}")

    # Find Frobenius norm of the difference
    frob_diff = jnp.linalg.norm(ag - true_grad, "fro")
    print(f"Frobenius norm of difference for {key}: {frob_diff}")
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 167.36it/s]
# Computing EKFAC components from scratch.
# Max absolute difference for linear_0: 3.814697265625e-06
# Frobenius norm of difference for linear_0: 6.594332262466196e-06
# Max absolute difference for linear_1: 7.62939453125e-06
# Frobenius norm of difference for linear_1: 9.22852359508397e-06
# Max absolute difference for output: 1.52587890625e-05
# Frobenius norm of difference for output: 3.4295830118935555e-05

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Quick Comparison of Hessian vs. KFAC vs. EKFAC

# %%
from config.hessian_approximation_config import KFACBuildConfig
from hessian_approximations.hessian.hessian import Hessian


config_comparison_linear = Config(
    dataset=RandomClassificationConfig(
        n_samples=10000,
        n_features=20,
        n_informative=4,
        n_classes=3,
        random_state=42,
        train_test_split=1,
    ),
    model=LinearModelConfig(loss="cross_entropy", hidden_dim=[]),
    training=TrainingConfig(
        epochs=200,
        batch_size=500,
        lr=0.001,
        optimizer="sgd",
        loss="cross_entropy",
    ),
)

build_config = KFACBuildConfig(use_pseudo_targets=True)
kfac_approx = KFAC.setup_with_run_and_build_config(
    full_config=config_comparison_linear,
    build_config=build_config,
    run_config=KFACRunConfig(use_eigenvalue_correction=False),
)

ekfac_approx = KFAC.setup_with_run_and_build_config(
    full_config=config_comparison_linear,
    build_config=build_config,
    run_config=KFACRunConfig(use_eigenvalue_correction=True),
)

hessian = Hessian(full_config=config_comparison_linear)

# Compute hessian for all 3 methods
h_kfac = kfac_approx.compute_hessian()

h_ekfac = ekfac_approx.compute_hessian()

h_true = hessian.compute_hessian()
h_true = h_true + ekfac_approx.damping() * jnp.eye(h_true.shape[0])

# Compute eigenvalues for all 3 methods
eigenvalues_kfac = jnp.linalg.eigvalsh(h_kfac)
eigenvalues_ekfac = jnp.linalg.eigvalsh(h_ekfac)
eigenvalues_true = jnp.linalg.eigvalsh(h_true)
# Out:
# 100%|██████████| 200/200 [00:06<00:00, 29.51it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.

# %%
# Plot the eigenvalues
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(eigenvalues_true, label="True Hessian", color="blue")
plt.plot(eigenvalues_kfac, label="KFAC", color="orange")
plt.plot(eigenvalues_ekfac, label="EKFAC", color="green")
plt.xlabel("Index")
plt.ylabel("Eigenvalue")
plt.title("Eigenvalue Comparison: True Hessian vs KFAC vs EKFAC")
plt.legend()
plt.grid(True)
plt.show()

# %%
from config.model_config import MLPModelConfig


config_comparison_mlp = Config(
    dataset=RandomClassificationConfig(
        n_samples=10000,
        n_features=20,
        n_classes=5,
        random_state=42,
        train_test_split=1,
    ),
    model=MLPModelConfig(loss="cross_entropy", hidden_dim=[10, 5]),
    training=TrainingConfig(
        epochs=200,
        batch_size=500,
        lr=0.001,
        optimizer="sgd",
        loss="cross_entropy",
    ),
)

build_config = KFACBuildConfig(use_pseudo_targets=True)
kfac_approx = KFAC.setup_with_run_and_build_config(
    full_config=config_comparison_mlp,
    build_config=build_config,
    run_config=KFACRunConfig(use_eigenvalue_correction=False),
)

ekfac_approx = KFAC.setup_with_run_and_build_config(
    full_config=config_comparison_mlp,
    build_config=build_config,
    run_config=KFACRunConfig(use_eigenvalue_correction=True),
)

hessian = Hessian(full_config=config_comparison_mlp)
# Compute hessian for all 3 methods
h_kfac = kfac_approx.compute_hessian()
h_ekfac = ekfac_approx.compute_hessian()
h_true = hessian.compute_hessian()
h_true = h_true + kfac_approx.damping() * jnp.eye(h_true.shape[0])

# Compute eigenvalues for all 3 methods
eigenvalues_kfac = jnp.linalg.eigvalsh(h_kfac)
eigenvalues_ekfac = jnp.linalg.eigvalsh(h_ekfac)
eigenvalues_true = jnp.linalg.eigvalsh(h_true)


# Plot the eigenvalues
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(eigenvalues_true, label="True Hessian", color="blue")
plt.plot(eigenvalues_kfac, label="KFAC", color="orange")
plt.plot(eigenvalues_ekfac, label="EKFAC", color="green")
plt.xlabel("Index")
plt.ylabel("Eigenvalue")
plt.title("Eigenvalue Comparison: True Hessian vs KFAC vs EKFAC (MLP)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 100%|██████████| 200/200 [00:07<00:00, 27.33it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.

# %% [markdown]
# ###  Comparing Full Hessians
#
# We want to check how well EKFAC approximates the full Hessian / Gauss-Newton-Hessian for different models: So we split up the analysis in the following categories:
# - Model size
# - Model complexity
#
# More concretely:
# 1. Linear Model with Single Linear Layer
# 2. Deep Linear Model with Multiple Linear Layers
# 3. MLP with Single Layer
# 4. MLP with Multiple Layers
#
# We want diversify also on the different models which we use, so we consider the following models for classification:
# 1. Random Classification
# 2. MNIST
# 3. CIFAR10

# %% [markdown]
# #### Linear Model with Single Linear Layer

# %%
# 10 balanced target total parameter sizes (≤ 5k)
n_samples = 2000
random_state = 42

# --- Gradual scaling from simple to complex ---
# total parameter size increases smoothly up to ~5k
target_param_sizes = np.linspace(20, 5000, num=10, dtype=int).tolist()
n_classes_list = [2, 3, 4, 5, 8, 10, 15, 20, 30, 40]

dataset_nums = []

for i, (target_params, n_classes) in enumerate(zip(target_param_sizes, n_classes_list)):
    # derive n_features
    n_features = max(10, int(target_params / n_classes))

    # scale informative features proportionally to n_features (min 2, max 100)
    n_informative = min(max(2, int(0.6 * n_features)), 100)

    dataset_nums.append(
        {
            "n_samples": n_samples,
            "n_features": n_features,
            "n_classes": n_classes,
            "n_informative": n_informative,
            "total_params": n_features * n_classes,
        }
    )


dataset_configs = {}
training_configs = {}

for dataset_num in dataset_nums:
    n_samples = dataset_num["n_samples"]
    n_features = dataset_num["n_features"]
    n_classes = dataset_num["n_classes"]
    n_informative = dataset_num["n_informative"]
    dataset_configs[f"random_classification_{n_samples}_{n_features}_{n_classes}"] = (
        RandomClassificationConfig(
            n_samples=n_samples,
            n_features=n_features,
            n_classes=n_classes,
            n_informative=n_informative,
            random_state=42,
            train_test_split=1,
        )
    )
    training_configs[f"random_classification_{n_samples}_{n_features}_{n_classes}"] = (
        TrainingConfig(
            epochs=100,
            lr=0.001,
            optimizer="sgd",
            batch_size=100,
            loss="cross_entropy",
        )
    )

# %%
import copy
from typing import Dict

from config.hessian_approximation_config import HessianApproximationConfig, HessianName
from hessian_approximations.hessian_approximations import HessianApproximation
from metrics.full_matrix_metrics import MATRIX_METRICS, compare_matrices


def compare_approximation_with_true_hessian(
    hessian_approxs: Dict[str, KFAC],
):
    results_dict = {}

    # assert that damping for all approximations is the same
    damping_value_1 = hessian_approxs["kfac"].damping()
    damping_value_2 = hessian_approxs["ekfac"].damping()

    assert jnp.isclose(damping_value_1, damping_value_2), (
        "Damping values for approximations are not the same."
    )

    config = copy.deepcopy(list(hessian_approxs.values())[0].full_config)
    config.hessian_approximation = HessianApproximationConfig(HessianName.HESSIAN)

    true_hessian = Hessian(full_config=config).compute_hessian()
    true_hessian = true_hessian + damping_value_1 * jnp.eye(true_hessian.shape[0])

    approximation_matrices = {}

    for approx_name, approx_method in hessian_approxs.items():
        approximation_matrix = approx_method.compute_hessian()
        approximation_matrices[approx_name] = approximation_matrix

        results_dict[approx_name] = compare_matrices(
            matrix_gt=true_hessian,
            matrix_approx=approximation_matrix,
            metrics=MATRIX_METRICS["all_matrix"],
        )
    return results_dict

# %%
# Linear Model Single Layer
results_dict = {}

for dataset_name, dataset_config in dataset_configs.items():
    linear_model_config = LinearModelConfig(loss="cross_entropy", hidden_dim=[])

    full_config = Config(
        dataset=dataset_config,
        model=linear_model_config,
        training=training_configs[dataset_name],
    )

    linear_hessian_configs: Dict[str, KFAC] = {
        "kfac": KFAC.setup_with_run_and_build_config(
            full_config=full_config,
            build_config=KFACBuildConfig(
                use_pseudo_targets=True,
            ),
            run_config=KFACRunConfig(
                use_eigenvalue_correction=False,
            ),
        ),
        "ekfac": KFAC.setup_with_run_and_build_config(
            full_config=full_config,
            build_config=KFACBuildConfig(
                use_pseudo_targets=True,
            ),
            run_config=KFACRunConfig(
                use_eigenvalue_correction=True,
            ),
        ),
    }

    print(f"Comparing Hessians for dataset: {dataset_name}")
    results_dict[dataset_name] = compare_approximation_with_true_hessian(
        hessian_approxs=linear_hessian_configs
    )
    print(f"Completed dataset: {dataset_name}")
# Out:
# Comparing Hessians for dataset: random_classification_2000_10_2
# 100%|██████████| 100/100 [00:00<00:00, 113.35it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Completed dataset: random_classification_2000_10_2
# Comparing Hessians for dataset: random_classification_2000_191_3
# 100%|██████████| 100/100 [00:00<00:00, 103.48it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Completed dataset: random_classification_2000_191_3
# Comparing Hessians for dataset: random_classification_2000_281_4
# 100%|██████████| 100/100 [00:00<00:00, 107.23it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Completed dataset: random_classification_2000_281_4
# Comparing Hessians for dataset: random_classification_2000_336_5
# 100%|██████████| 100/100 [00:01<00:00, 99.15it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Completed dataset: random_classification_2000_336_5
# Comparing Hessians for dataset: random_classification_2000_279_8
# 100%|██████████| 100/100 [00:00<00:00, 107.52it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Completed dataset: random_classification_2000_279_8
# Comparing Hessians for dataset: random_classification_2000_278_10
# 100%|██████████| 100/100 [00:00<00:00, 105.80it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Completed dataset: random_classification_2000_278_10
# Comparing Hessians for dataset: random_classification_2000_222_15
# 100%|██████████| 100/100 [00:01<00:00, 91.31it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Completed dataset: random_classification_2000_222_15
# Comparing Hessians for dataset: random_classification_2000_194_20
# 100%|██████████| 100/100 [00:01<00:00, 89.95it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Completed dataset: random_classification_2000_194_20
# Comparing Hessians for dataset: random_classification_2000_148_30
# 100%|██████████| 100/100 [00:01<00:00, 89.10it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Completed dataset: random_classification_2000_148_30
# Comparing Hessians for dataset: random_classification_2000_125_40
# 100%|██████████| 100/100 [00:01<00:00, 89.06it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Completed dataset: random_classification_2000_125_40

# %%
print("Final Results:")
for dataset_name, result in results_dict.items():
    print(f"Dataset: {dataset_name}")
    for approx_name, metrics in result.items():
        print(f"  Approximation: {approx_name}")
        for metric_name, value in metrics.items():
            print(f"    {metric_name}: {value}")
# Out:
# Final Results:
# Dataset: random_classification_2000_10_2
#   Approximation: kfac
#     relative_frobenius: 0.22640233744278704
#     max_elementwise: 0.18786367774009705
#     spectral: 0.5415422370754831
#     spectral_relative: 0.25707548523033813
#     cosine_similarity: 0.9761433241976248
#     eigenvalue_max: 0.3016852536821588
#     eigenvalues_l2_distance: 0.15808270034024277
#     trace_distance: 0.026405757665634154
#     condition_number_log_ratio: 0.07549071425199205
#   Approximation: ekfac
#     relative_frobenius: 0.18469988185968125
#     max_elementwise: 0.09059270098805428
#     spectral: 0.31260941884741134
#     spectral_relative: 0.148398799827262
#     cosine_similarity: 0.9884932949861372
#     eigenvalue_max: 0.24928657204153382
#     eigenvalues_l2_distance: 0.13064573005214558
#     trace_distance: 0.03805444836616516
#     condition_number_log_ratio: 0.09566545373201674
# Dataset: random_classification_2000_191_3
#   Approximation: kfac
#     relative_frobenius: 0.10524482580039957
#     max_elementwise: 9.615856170654297
#     spectral: 21.629005334650248
#     spectral_relative: 0.1037697797575767
#     cosine_similarity: 0.9950434804848461
#     eigenvalue_max: 15.605410025925124
#     eigenvalues_l2_distance: 0.05039154863052732
#     trace_distance: 0.1034299418798292
#     condition_number_log_ratio: 0.0034317473980243207
#   Approximation: ekfac
#     relative_frobenius: 0.09814914619204182
#     max_elementwise: 6.852586776018143
#     spectral: 18.78882990328563
#     spectral_relative: 0.09014343058314515
#     cosine_similarity: 0.9958095071904967
#     eigenvalue_max: 13.738909171432937
#     eigenvalues_l2_distance: 0.047800684489786
#     trace_distance: 0.12410711894952814
#     condition_number_log_ratio: 0.009874771079664946
# Dataset: random_classification_2000_281_4
#   Approximation: kfac
#     relative_frobenius: 0.12206164052747598
#     max_elementwise: 13.597217634320259
#     spectral: 26.33533124506419
#     spectral_relative: 0.14066014273963565
#     cosine_similarity: 0.9931858479793344
#     eigenvalue_max: 17.370675141922874
#     eigenvalues_l2_distance: 0.06747107197466205
#     trace_distance: 0.08866766314569105
#     condition_number_log_ratio: 0.09735067488140814
#   Approximation: ekfac
#     relative_frobenius: 0.12252953090921777
#     max_elementwise: 18.675868913531303
#     spectral: 29.28154935515205
#     spectral_relative: 0.1563962447863767
#     cosine_similarity: 0.9927928750392905
#     eigenvalue_max: 10.840155546553689
#     eigenvalues_l2_distance: 0.04317466881781885
#     trace_distance: 0.011409101716086958
#     condition_number_log_ratio: 0.056339663253357486
# Dataset: random_classification_2000_336_5
#   Approximation: kfac
#     relative_frobenius: 0.11665681356591867
#     max_elementwise: 4.856886923313141
#     spectral: 15.181114542489553
#     spectral_relative: 0.10949618217505099
#     cosine_similarity: 0.9931740598697274
#     eigenvalue_max: 4.527482421558119
#     eigenvalues_l2_distance: 0.03345222417609912
#     trace_distance: 0.0001505955344154721
#     condition_number_log_ratio: 0.024876741281424586
#   Approximation: ekfac
#     relative_frobenius: 0.12310008407136724
#     max_elementwise: 9.322455137968063
#     spectral: 18.296329779091003
#     spectral_relative: 0.13196516323086938
#     cosine_similarity: 0.9924350808684224
#     eigenvalue_max: 8.46886449366464
#     eigenvalues_l2_distance: 0.03968447331442071
#     trace_distance: 0.0022321007081440515
#     condition_number_log_ratio: 0.018005224355782445
# Dataset: random_classification_2000_279_8
#   Approximation: kfac
#     relative_frobenius: 0.15658066327307463
#     max_elementwise: 12.621796235442162
#     spectral: 19.069040691720616
#     spectral_relative: 0.1794769297323267
#     cosine_similarity: 0.987898971772813
#     eigenvalue_max: 4.0877134120525085
#     eigenvalues_l2_distance: 0.03671583017153057
#     trace_distance: 0.014717519443522217
#     condition_number_log_ratio: 0.03783402256123303
#   Approximation: ekfac
#     relative_frobenius: 0.14082197986144476
#     max_elementwise: 6.786979094147682
#     spectral: 16.083758316894812
#     spectral_relative: 0.15137958998254092
#     cosine_similarity: 0.990045703487197
#     eigenvalue_max: 3.810623858687265
#     eigenvalues_l2_distance: 0.037970538001459664
#     trace_distance: 0.009737889452647138
#     condition_number_log_ratio: 0.004383419076125605
# Dataset: random_classification_2000_278_10
#   Approximation: kfac
#     relative_frobenius: 0.15817415704073182
#     max_elementwise: 9.076362706720829
#     spectral: 14.130785623031013
#     spectral_relative: 0.1737573431029004
#     cosine_similarity: 0.9876648266004842
#     eigenvalue_max: 3.9165008843841917
#     eigenvalues_l2_distance: 0.04592220647126526
#     trace_distance: 0.0200440568956647
#     condition_number_log_ratio: 0.027033972416433905
#   Approximation: ekfac
#     relative_frobenius: 0.16627877650412648
#     max_elementwise: 9.654399774968624
#     spectral: 16.948275816840546
#     spectral_relative: 0.20840223995116292
#     cosine_similarity: 0.989071874332682
#     eigenvalue_max: 7.007765991846384
#     eigenvalues_l2_distance: 0.07800899673390864
#     trace_distance: 0.06711700400672585
#     condition_number_log_ratio: 0.04841535059026203
# Dataset: random_classification_2000_222_15
#   Approximation: kfac
#     relative_frobenius: 0.15322663007690326
#     max_elementwise: 7.612325668334961
#     spectral: 16.331063379722192
#     spectral_relative: 0.1982887736024342
#     cosine_similarity: 0.9883362927543742
#     eigenvalue_max: 9.178046498241159
#     eigenvalues_l2_distance: 0.04965958865052999
#     trace_distance: 0.014736216026428226
#     condition_number_log_ratio: 0.1181165073986925
#   Approximation: ekfac
#     relative_frobenius: 0.1692103092574648
#     max_elementwise: 11.221708297729492
#     spectral: 17.479114801398033
#     spectral_relative: 0.21222820321234526
#     cosine_similarity: 0.9859276612833062
#     eigenvalue_max: 9.123969349803659
#     eigenvalues_l2_distance: 0.05610251539447647
#     trace_distance: 0.008689739862764561
#     condition_number_log_ratio: 0.11736882673463
# Dataset: random_classification_2000_194_20
#   Approximation: kfac
#     relative_frobenius: 0.19360032743581632
#     max_elementwise: 11.375347070395947
#     spectral: 16.361147959761876
#     spectral_relative: 0.285398869367115
#     cosine_similarity: 0.9816847937349169
#     eigenvalue_max: 2.7540080490231205
#     eigenvalues_l2_distance: 0.05745758655696295
#     trace_distance: 0.02177552629127791
#     condition_number_log_ratio: 0.004060640194839316
#   Approximation: ekfac
#     relative_frobenius: 0.18025993095324347
#     max_elementwise: 7.933105401694775
#     spectral: 13.23881904506595
#     spectral_relative: 0.23093391713772157
#     cosine_similarity: 0.9836198698030306
#     eigenvalue_max: 3.6032780084401566
#     eigenvalues_l2_distance: 0.05910840238226035
#     trace_distance: 0.0009018803908268816
#     condition_number_log_ratio: 0.04339180960374467
# Dataset: random_classification_2000_148_30
#   Approximation: kfac
#     relative_frobenius: 0.20992924191815718
#     max_elementwise: 6.367854155600071
#     spectral: 9.33059646399157
#     spectral_relative: 0.2937912276243427
#     cosine_similarity: 0.9779476824505318
#     eigenvalue_max: 4.444544025565133
#     eigenvalues_l2_distance: 0.06303406368986658
#     trace_distance: 0.007146535557065461
#     condition_number_log_ratio: 0.13099264375417707
#   Approximation: ekfac
#     relative_frobenius: 0.19825168985374939
#     max_elementwise: 6.600922621786594
#     spectral: 8.696109651298876
#     spectral_relative: 0.27381322725407486
#     cosine_similarity: 0.9801690304557036
#     eigenvalue_max: 4.014997669363961
#     eigenvalues_l2_distance: 0.06566596485599226
#     trace_distance: 0.002007760307206227
#     condition_number_log_ratio: 0.11907028428762434
# Dataset: random_classification_2000_125_40
#   Approximation: kfac
#     relative_frobenius: 0.22748438842716967
#     max_elementwise: 5.01820857077837
#     spectral: 6.131507117965256
#     spectral_relative: 0.2942569450468875
#     cosine_similarity: 0.9740551805857771
#     eigenvalue_max: 1.4699005682153405
#     eigenvalues_l2_distance: 0.07043425767980604
#     trace_distance: 0.004364978184737265
#     condition_number_log_ratio: 0.008917028794948934
#   Approximation: ekfac
#     relative_frobenius: 0.21529510564212553
#     max_elementwise: 3.7968024536967278
#     spectral: 6.328331542621159
#     spectral_relative: 0.30370273917149365
#     cosine_similarity: 0.9766106403636563
#     eigenvalue_max: 1.1254392680360592
#     eigenvalues_l2_distance: 0.07085025784658738
#     trace_distance: 0.001489978184737265
#     condition_number_log_ratio: 0.006248171220486043

# %%
# Extract data for plotting
datasets = list(results_dict.keys())
parameter_sizes = []
max_elementwise_kfac = []
max_elementwise_ekfac = []
spectral_norm_kfac = []
spectral_norm_ekfac = []
cosine_sim_kfac = []
cosine_sim_ekfac = []
eigenval_l2_kfac = []
eigenval_l2_ekfac = []

for dataset in datasets:
    # Extract n_features and n_classes from dataset name
    parts = dataset.split("_")
    n_features = int(parts[3])
    n_classes = int(parts[4])
    param_size = n_features * n_classes
    parameter_sizes.append(param_size)

    # Extract metrics for KFAC and EKFAC
    kfac_metrics = results_dict[dataset]["kfac"]
    ekfac_metrics = results_dict[dataset]["ekfac"]

    max_elementwise_kfac.append(kfac_metrics["max_elementwise"])
    max_elementwise_ekfac.append(ekfac_metrics["max_elementwise"])
    spectral_norm_kfac.append(kfac_metrics["spectral"])
    spectral_norm_ekfac.append(ekfac_metrics["spectral"])
    cosine_sim_kfac.append(kfac_metrics["cosine_similarity"])
    cosine_sim_ekfac.append(ekfac_metrics["cosine_similarity"])
    eigenval_l2_kfac.append(kfac_metrics["eigenvalues_l2_distance"])
    eigenval_l2_ekfac.append(ekfac_metrics["eigenvalues_l2_distance"])

# Create subplot with 4 plots side by side
fig, axes = plt.subplots(1, 4, figsize=(20, 5))

# Plot 1: Max Elementwise
axes[0].plot(parameter_sizes, max_elementwise_kfac, "o-", label="KFAC", color="orange")
axes[0].plot(parameter_sizes, max_elementwise_ekfac, "s-", label="EKFAC", color="green")
axes[0].set_xlabel("Parameter Size (n_features × n_classes)")
axes[0].set_ylabel("Max Elementwise Difference")
axes[0].set_title("Max Elementwise Difference")
axes[0].legend()
axes[0].grid(True)

# Plot 2: Spectral Norm
axes[1].plot(parameter_sizes, spectral_norm_kfac, "o-", label="KFAC", color="orange")
axes[1].plot(parameter_sizes, spectral_norm_ekfac, "s-", label="EKFAC", color="green")
axes[1].set_xlabel("Parameter Size (n_features × n_classes)")
axes[1].set_ylabel("Spectral Norm")
axes[1].set_title("Spectral Norm")
axes[1].legend()
axes[1].grid(True)

# Plot 3: Cosine Similarity
axes[2].plot(parameter_sizes, cosine_sim_kfac, "o-", label="KFAC", color="orange")
axes[2].plot(parameter_sizes, cosine_sim_ekfac, "s-", label="EKFAC", color="green")
axes[2].set_xlabel("Parameter Size (n_features × n_classes)")
axes[2].set_ylabel("Cosine Similarity")
axes[2].set_title("Cosine Similarity")
axes[2].legend()
axes[2].grid(True)

# Plot 4: Eigenvalues L2 Distance
axes[3].plot(parameter_sizes, eigenval_l2_kfac, "o-", label="KFAC", color="orange")
axes[3].plot(parameter_sizes, eigenval_l2_ekfac, "s-", label="EKFAC", color="green")
axes[3].set_xlabel("Parameter Size (n_features × n_classes)")
axes[3].set_ylabel("Eigenvalues L2 Distance")
axes[3].set_title("Eigenvalues L2 Distance")
axes[3].legend()
axes[3].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Multi-Layer Setup for Random Classification

# %%
# --- Multi-Layer Linear Setup (hidden_dim ≠ []) ---
import numpy as np
from typing import Dict
from hessian_approximations.hessian_approximations import HessianApproximation

# 10 balanced target total parameter sizes (≤ 5k)
n_samples = 2000
random_state = 42

target_param_sizes = np.linspace(20, 2000, num=10, dtype=int).tolist()
n_classes_list = [5] * 10  # keep n_classes constant for simplicity


def choose_hidden_dims(target_params: int):
    """
    Choose hidden layer sizes dynamically so that total params ≈ target_params.
    Formula for params: n_features*h1 + h1*h2 + ... + hL*n_classes
    """
    # simple heuristic: one or two hidden layers that fit target budget
    if target_params <= 1000:
        return [10]
    elif target_params <= 3000:
        return [10, 5]
    else:
        return [20, 10, 5]


dataset_nums = []

for target_params, n_classes in zip(target_param_sizes, n_classes_list):
    # derive n_features
    n_features = max(10, int(target_params / n_classes))
    n_informative = min(max(2, int(0.6 * n_features)), 100)

    hidden_dims = choose_hidden_dims(target_params)

    total_params = n_features * hidden_dims[0]
    for i in range(len(hidden_dims) - 1):
        total_params += hidden_dims[i] * hidden_dims[i + 1]
    total_params += hidden_dims[-1] * n_classes

    dataset_nums.append(
        {
            "n_samples": n_samples,
            "n_features": n_features,
            "n_classes": n_classes,
            "n_informative": n_informative,
            "hidden_dims": hidden_dims,
            "total_params": total_params,
        }
    )

dataset_configs = {}
training_configs = {}
total_params_dict = {}

for dataset_num in dataset_nums:
    n_samples = dataset_num["n_samples"]
    n_features = dataset_num["n_features"]
    n_classes = dataset_num["n_classes"]
    n_informative = dataset_num["n_informative"]
    dataset_configs[f"random_classification_{n_samples}_{n_features}_{n_classes}"] = (
        RandomClassificationConfig(
            n_samples=n_samples,
            n_features=n_features,
            n_classes=n_classes,
            n_informative=n_informative,
            random_state=42,
            train_test_split=1,
        )
    )
    training_configs[f"random_classification_{n_samples}_{n_features}_{n_classes}"] = (
        TrainingConfig(
            epochs=100,
            lr=0.001,
            optimizer="sgd",
            batch_size=100,
            loss="cross_entropy",
        )
    )
    total_params_dict[f"random_classification_{n_samples}_{n_features}_{n_classes}"] = (
        dataset_num["total_params"]
    )


# --- Experiment loop ---
results_dict = {}

for dataset_name, dataset_config in dataset_configs.items():
    n_features = dataset_config.n_features
    n_classes = dataset_config.n_classes

    multi_linear_model_config = LinearModelConfig(
        loss="cross_entropy",
        hidden_dim=hidden_dims,
    )

    full_config = Config(
        dataset=dataset_config,
        model=multi_linear_model_config,
        training=training_configs[dataset_name],
    )

    multi_linear_hessian_configs: Dict[str, KFAC] = {
        "kfac": KFAC.setup_with_run_and_build_config(
            full_config=full_config,
            build_config=KFACBuildConfig(
                use_pseudo_targets=True,
                recalc_ekfac_components=True,
            ),
            run_config=KFACRunConfig(
                use_eigenvalue_correction=False,
            ),
        ),
        "ekfac": KFAC.setup_with_run_and_build_config(
            full_config=full_config,
            build_config=KFACBuildConfig(
                use_pseudo_targets=True,
            ),
            run_config=KFACRunConfig(
                use_eigenvalue_correction=True,
            ),
        ),
    }

    print(f"Processing dataset: {dataset_name} | Hidden dims: {hidden_dims}")
    results_dict[dataset_name] = compare_approximation_with_true_hessian(
        hessian_approxs=multi_linear_hessian_configs
    )

    print(f"Completed dataset: {dataset_name}")
# Out:
# Processing dataset: random_classification_2000_10_5 | Hidden dims: [10, 5]
# 100%|██████████| 100/100 [00:00<00:00, 111.36it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Computing EKFAC components from scratch.
# Completed dataset: random_classification_2000_10_5
# Processing dataset: random_classification_2000_48_5 | Hidden dims: [10, 5]
# 100%|██████████| 100/100 [00:00<00:00, 102.31it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Computing EKFAC components from scratch.
# Completed dataset: random_classification_2000_48_5
# Processing dataset: random_classification_2000_92_5 | Hidden dims: [10, 5]
# 100%|██████████| 100/100 [00:01<00:00, 97.90it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Computing EKFAC components from scratch.
# Completed dataset: random_classification_2000_92_5
# Processing dataset: random_classification_2000_136_5 | Hidden dims: [10, 5]
# 100%|██████████| 100/100 [00:01<00:00, 97.02it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Computing EKFAC components from scratch.
# Completed dataset: random_classification_2000_136_5
# Processing dataset: random_classification_2000_180_5 | Hidden dims: [10, 5]
# 100%|██████████| 100/100 [00:01<00:00, 95.33it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Computing EKFAC components from scratch.
# Completed dataset: random_classification_2000_180_5
# Processing dataset: random_classification_2000_224_5 | Hidden dims: [10, 5]
# 100%|██████████| 100/100 [00:01<00:00, 92.60it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Computing EKFAC components from scratch.
# Completed dataset: random_classification_2000_224_5
# Processing dataset: random_classification_2000_268_5 | Hidden dims: [10, 5]
# 100%|██████████| 100/100 [00:01<00:00, 89.38it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Computing EKFAC components from scratch.
# Completed dataset: random_classification_2000_268_5
# Processing dataset: random_classification_2000_312_5 | Hidden dims: [10, 5]
# 100%|██████████| 100/100 [00:01<00:00, 85.69it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Computing EKFAC components from scratch.
# Completed dataset: random_classification_2000_312_5
# Processing dataset: random_classification_2000_356_5 | Hidden dims: [10, 5]
# 100%|██████████| 100/100 [00:01<00:00, 86.04it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Computing EKFAC components from scratch.
# Completed dataset: random_classification_2000_356_5
# Processing dataset: random_classification_2000_400_5 | Hidden dims: [10, 5]
# 100%|██████████| 100/100 [00:01<00:00, 85.02it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Computing EKFAC components from scratch.
# Completed dataset: random_classification_2000_400_5

# %%
# Print the final results as before

print("Final Results for Multi-Layer Linear Models:")
for dataset_name, result in results_dict.items():
    print(f"Dataset: {dataset_name}")
    for approx_name, metrics in result.items():
        print(f"  Approximation: {approx_name}")
        for metric_name, value in metrics.items():
            print(f"    {metric_name}: {value}")
# Out:
# Final Results for Multi-Layer Linear Models:
# Dataset: random_classification_2000_10_5
#   Approximation: kfac
#     relative_frobenius: 0.7613154164326408
#     max_elementwise: 0.3700261116027832
#     spectral: 2.3373800150371267
#     spectral_relative: 0.5866412795515987
#     cosine_similarity: 0.6571078133842103
#     eigenvalue_max: 1.607022606893945
#     eigenvalues_l2_distance: 0.37614694748328437
#     trace_distance: 0.021132181675306387
#     condition_number_log_ratio: 3.625976932115055
#   Approximation: ekfac
#     relative_frobenius: 0.7513681724105883
#     max_elementwise: 0.3700261116027832
#     spectral: 2.578479642926923
#     spectral_relative: 0.6471530462710715
#     cosine_similarity: 0.6599298707728657
#     eigenvalue_max: 2.0499407883133176
#     eigenvalues_l2_distance: 0.45647505847410214
#     trace_distance: 0.0013009085346545493
#     condition_number_log_ratio: 3.8311566234297523
# Dataset: random_classification_2000_48_5
#   Approximation: kfac
#     relative_frobenius: 0.5987542997837743
#     max_elementwise: 1.5735595226287842
#     spectral: 7.666429415850737
#     spectral_relative: 0.4552187207118857
#     cosine_similarity: 0.8025993556206964
#     eigenvalue_max: 3.5280903748632717
#     eigenvalues_l2_distance: 0.19588927972358072
#     trace_distance: 0.01771580017599705
#     condition_number_log_ratio: 2.800442514141288
#   Approximation: ekfac
#     relative_frobenius: 0.595791558751967
#     max_elementwise: 1.5735595226287842
#     spectral: 8.070219585507152
#     spectral_relative: 0.4791950510863604
#     cosine_similarity: 0.8033704002044958
#     eigenvalue_max: 4.050169842636709
#     eigenvalues_l2_distance: 0.2452547856293702
#     trace_distance: 0.0043685064206386475
#     condition_number_log_ratio: 2.8394616219598916
# Dataset: random_classification_2000_92_5
#   Approximation: kfac
#     relative_frobenius: 0.4850745261913949
#     max_elementwise: 3.630995035171509
#     spectral: 17.392153356443945
#     spectral_relative: 0.41086512518973195
#     cosine_similarity: 0.8744755128873453
#     eigenvalue_max: 5.65249394283294
#     eigenvalues_l2_distance: 0.15288042233550408
#     trace_distance: 0.0028672109437572896
#     condition_number_log_ratio: 7.200285324978699
#   Approximation: ekfac
#     relative_frobenius: 0.4849059254065295
#     max_elementwise: 3.630995035171509
#     spectral: 17.90630431357559
#     spectral_relative: 0.4230112173405377
#     cosine_similarity: 0.8746412542433806
#     eigenvalue_max: 6.836608620321577
#     eigenvalues_l2_distance: 0.15470876110216616
#     trace_distance: 0.004326779025620851
#     condition_number_log_ratio: 7.240321049618592
# Dataset: random_classification_2000_136_5
#   Approximation: kfac
#     relative_frobenius: 0.34331775189714564
#     max_elementwise: 3.6967859268188477
#     spectral: 19.048166304908293
#     spectral_relative: 0.26363510122902756
#     cosine_similarity: 0.9397234696373459
#     eigenvalue_max: 7.8002595599332665
#     eigenvalues_l2_distance: 0.10876828466582586
#     trace_distance: 0.007047753066200931
#     condition_number_log_ratio: 3.492328151752311
#   Approximation: ekfac
#     relative_frobenius: 0.34213381980187624
#     max_elementwise: 3.6967859268188477
#     spectral: 17.371260412600112
#     spectral_relative: 0.24042597718036243
#     cosine_similarity: 0.9396547715582366
#     eigenvalue_max: 4.482563942257485
#     eigenvalues_l2_distance: 0.08664837331634319
#     trace_distance: 0.0019046373214274125
#     condition_number_log_ratio: 3.441141590167838
# Dataset: random_classification_2000_180_5
#   Approximation: kfac
#     relative_frobenius: 0.3584018832556985
#     max_elementwise: 8.740726470947266
#     spectral: 23.966993955744393
#     spectral_relative: 0.26955778846625184
#     cosine_similarity: 0.9336062863341839
#     eigenvalue_max: 8.730671764350049
#     eigenvalues_l2_distance: 0.09266904257439271
#     trace_distance: 0.0016257632435609896
#     condition_number_log_ratio: 2.53816435243845
#   Approximation: ekfac
#     relative_frobenius: 0.3605288658750125
#     max_elementwise: 8.740726470947266
#     spectral: 24.054341324361577
#     spectral_relative: 0.2705401879927119
#     cosine_similarity: 0.9327935187595257
#     eigenvalue_max: 6.040077400712601
#     eigenvalues_l2_distance: 0.08221352849946649
#     trace_distance: 0.0038314924102276562
#     condition_number_log_ratio: 2.470109676382542
# Dataset: random_classification_2000_224_5
#   Approximation: kfac
#     relative_frobenius: 0.29870023144686336
#     max_elementwise: 5.9744086265563965
#     spectral: 27.567431739955662
#     spectral_relative: 0.23421670540843942
#     cosine_similarity: 0.9545343237063033
#     eigenvalue_max: 5.252949826026395
#     eigenvalues_l2_distance: 0.04912685114822194
#     trace_distance: 0.009053450605689224
#     condition_number_log_ratio: 3.5448600465868942
#   Approximation: ekfac
#     relative_frobenius: 0.29952550670048234
#     max_elementwise: 5.9744086265563965
#     spectral: 29.86997992680549
#     spectral_relative: 0.25377947264244693
#     cosine_similarity: 0.9541581828281719
#     eigenvalue_max: 8.235921017432645
#     eigenvalues_l2_distance: 0.06688913917736691
#     trace_distance: 0.008039926064802137
#     condition_number_log_ratio: 3.5707089120959274
# Dataset: random_classification_2000_268_5
#   Approximation: kfac
#     relative_frobenius: 0.3022814037928245
#     max_elementwise: 6.819421291351318
#     spectral: 30.929835442034992
#     spectral_relative: 0.2548082017803288
#     cosine_similarity: 0.9548947244893429
#     eigenvalue_max: 4.757405246042481
#     eigenvalues_l2_distance: 0.04559296351315146
#     trace_distance: 0.020571174999925487
#     condition_number_log_ratio: 2.8234977608858465
#   Approximation: ekfac
#     relative_frobenius: 0.29925573148932005
#     max_elementwise: 6.819421291351318
#     spectral: 30.96228516256899
#     spectral_relative: 0.2550755311992983
#     cosine_similarity: 0.9541746519191596
#     eigenvalue_max: 10.595373669966534
#     eigenvalues_l2_distance: 0.06869044582642607
#     trace_distance: 0.005334318715896451
#     condition_number_log_ratio: 2.9317088013826726
# Dataset: random_classification_2000_312_5
#   Approximation: kfac
#     relative_frobenius: 0.284952758529853
#     max_elementwise: 5.326663970947266
#     spectral: 24.627085443621084
#     spectral_relative: 0.22451479072891095
#     cosine_similarity: 0.9586968044469469
#     eigenvalue_max: 6.980966491285713
#     eigenvalues_l2_distance: 0.06777024731646786
#     trace_distance: 0.004165974504814275
#     condition_number_log_ratio: 2.755505301242513
#   Approximation: ekfac
#     relative_frobenius: 0.2870165880367996
#     max_elementwise: 5.326663970947266
#     spectral: 25.435227064558255
#     spectral_relative: 0.23188227834003744
#     cosine_similarity: 0.9581357772561072
#     eigenvalue_max: 8.630632323805244
#     eigenvalues_l2_distance: 0.07790940113063467
#     trace_distance: 0.00167986645023681
#     condition_number_log_ratio: 2.780313231235189
# Dataset: random_classification_2000_356_5
#   Approximation: kfac
#     relative_frobenius: 0.1983264203753618
#     max_elementwise: 5.93280553817749
#     spectral: 22.72532567880553
#     spectral_relative: 0.1590065370476765
#     cosine_similarity: 0.9804766909414815
#     eigenvalue_max: 8.761002138550367
#     eigenvalues_l2_distance: 0.05604495252200768
#     trace_distance: 0.007437015933521409
#     condition_number_log_ratio: 4.510980462757484
#   Approximation: ekfac
#     relative_frobenius: 0.2103104283190963
#     max_elementwise: 7.49473100155592
#     spectral: 25.994676080839657
#     spectral_relative: 0.18188181255176775
#     cosine_similarity: 0.9776525149763444
#     eigenvalue_max: 10.82113953510472
#     eigenvalues_l2_distance: 0.06944292265030902
#     trace_distance: 0.002506181274821272
#     condition_number_log_ratio: 4.4199222085155405
# Dataset: random_classification_2000_400_5
#   Approximation: kfac
#     relative_frobenius: 0.31342571133851765
#     max_elementwise: 9.126424789428711
#     spectral: 37.40318719436725
#     spectral_relative: 0.2561948062312991
#     cosine_similarity: 0.9503288091699882
#     eigenvalue_max: 14.273621952087467
#     eigenvalues_l2_distance: 0.09189184188941349
#     trace_distance: 0.01196107058043083
#     condition_number_log_ratio: 3.5097822947989705
#   Approximation: ekfac
#     relative_frobenius: 0.31726227547826813
#     max_elementwise: 9.126424789428711
#     spectral: 39.42078385148548
#     spectral_relative: 0.2700144249161251
#     cosine_similarity: 0.9500095727489329
#     eigenvalue_max: 17.173036014587467
#     eigenvalues_l2_distance: 0.10985147266238995
#     trace_distance: 0.016168826763329605
#     condition_number_log_ratio: 3.5310787959586385

# %%
# Plot results

# Extract data for plotting
datasets = list(results_dict.keys())
parameter_sizes = []
max_elementwise_kfac = []
max_elementwise_ekfac = []
spectral_norm_kfac = []
spectral_norm_ekfac = []
cosine_sim_kfac = []
cosine_sim_ekfac = []
eigenval_l2_kfac = []
eigenval_l2_ekfac = []

for dataset in datasets:
    # Extract n_features and n_classes from dataset name
    parts = dataset.split("_")
    n_features = int(parts[3])
    n_classes = int(parts[4])
    param_size = total_params_dict[
        f"random_classification_{n_samples}_{n_features}_{n_classes}"
    ]
    parameter_sizes.append(param_size)

    # Extract metrics for KFAC and EKFAC
    kfac_metrics = results_dict[dataset]["kfac"]
    ekfac_metrics = results_dict[dataset]["ekfac"]

    max_elementwise_kfac.append(kfac_metrics["max_elementwise"])
    max_elementwise_ekfac.append(ekfac_metrics["max_elementwise"])
    spectral_norm_kfac.append(kfac_metrics["spectral"])
    spectral_norm_ekfac.append(ekfac_metrics["spectral"])
    cosine_sim_kfac.append(kfac_metrics["cosine_similarity"])
    cosine_sim_ekfac.append(ekfac_metrics["cosine_similarity"])
    eigenval_l2_kfac.append(kfac_metrics["eigenvalues_l2_distance"])
    eigenval_l2_ekfac.append(ekfac_metrics["eigenvalues_l2_distance"])

# Create subplot with 4 plots side by side
fig, axes = plt.subplots(1, 4, figsize=(20, 5))

# Plot 1: Max Elementwise
axes[0].plot(parameter_sizes, max_elementwise_kfac, "o-", label="KFAC", color="orange")
axes[0].plot(parameter_sizes, max_elementwise_ekfac, "s-", label="EKFAC", color="green")
axes[0].set_xlabel("Parameter Size")
axes[0].set_ylabel("Max Elementwise Difference")
axes[0].set_title("Max Elementwise Difference")
axes[0].legend()
axes[0].grid(True)

# Plot 2: Spectral Norm
axes[1].plot(parameter_sizes, spectral_norm_kfac, "o-", label="KFAC", color="orange")
axes[1].plot(parameter_sizes, spectral_norm_ekfac, "s-", label="EKFAC", color="green")
axes[1].set_xlabel("Parameter Size")
axes[1].set_ylabel("Spectral Norm")
axes[1].set_title("Spectral Norm")
axes[1].legend()
axes[1].grid(True)

# Plot 3: Cosine Similarity
axes[2].plot(parameter_sizes, cosine_sim_kfac, "o-", label="KFAC", color="orange")
axes[2].plot(parameter_sizes, cosine_sim_ekfac, "s-", label="EKFAC", color="green")
axes[2].set_xlabel("Parameter Size")
axes[2].set_ylabel("Cosine Similarity")
axes[2].set_title("Cosine Similarity")
axes[2].legend()
axes[2].grid(True)

# Plot 4: Eigenvalues L2 Distance
axes[3].plot(parameter_sizes, eigenval_l2_kfac, "o-", label="KFAC", color="orange")
axes[3].plot(parameter_sizes, eigenval_l2_ekfac, "s-", label="EKFAC", color="green")
axes[3].set_xlabel("Parameter Size ")
axes[3].set_ylabel("Eigenvalues L2 Distance")
axes[3].set_title("Eigenvalues L2 Distance")
axes[3].legend()
axes[3].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### MLP Setup

# %%
# --- Multi-Layer MLP Setup (hidden_dim ≠ [])---
import numpy as np
from typing import Dict
from hessian_approximations.hessian_approximations import HessianApproximation

# 10 balanced target total parameter sizes (≤ 5k)
n_samples = 2000
random_state = 42

target_param_sizes = np.linspace(20, 2000, num=10, dtype=int).tolist()
n_classes_list = [5] * 10  # keep n_classes constant for simplicity


def choose_hidden_dims(target_params: int):
    """
    Choose hidden layer sizes dynamically so that total params ≈ target_params.
    Formula for params: n_features*h1 + h1*h2 + ... + hL*n_classes
    """
    # simple heuristic: one or two hidden layers that fit target budget
    if target_params <= 1000:
        return [10]
    elif target_params <= 3000:
        return [10, 5]
    else:
        return [20, 10, 5]


dataset_nums = []

for target_params, n_classes in zip(target_param_sizes, n_classes_list):
    # derive n_features
    n_features = max(10, int(target_params / n_classes))
    n_informative = min(max(2, int(0.6 * n_features)), 100)

    hidden_dims = choose_hidden_dims(target_params)

    total_params = n_features * hidden_dims[0]
    for i in range(len(hidden_dims) - 1):
        total_params += hidden_dims[i] * hidden_dims[i + 1]
    total_params += hidden_dims[-1] * n_classes

    dataset_nums.append(
        {
            "n_samples": n_samples,
            "n_features": n_features,
            "n_classes": n_classes,
            "n_informative": n_informative,
            "hidden_dims": hidden_dims,
            "total_params": total_params,
        }
    )

dataset_configs = {}
training_configs = {}
total_params_dict = {}

for dataset_num in dataset_nums:
    n_samples = dataset_num["n_samples"]
    n_features = dataset_num["n_features"]
    n_classes = dataset_num["n_classes"]
    n_informative = dataset_num["n_informative"]
    dataset_configs[f"random_classification_{n_samples}_{n_features}_{n_classes}"] = (
        RandomClassificationConfig(
            n_samples=n_samples,
            n_features=n_features,
            n_classes=n_classes,
            n_informative=n_informative,
            random_state=42,
            train_test_split=1,
        )
    )
    training_configs[f"random_classification_{n_samples}_{n_features}_{n_classes}"] = (
        TrainingConfig(
            epochs=100,
            lr=0.001,
            optimizer="sgd",
            batch_size=100,
            loss="cross_entropy",
        )
    )
    total_params_dict[f"random_classification_{n_samples}_{n_features}_{n_classes}"] = (
        dataset_num["total_params"]
    )


# --- Experiment loop ---
results_dict = {}

for dataset_name, dataset_config in dataset_configs.items():
    n_features = dataset_config.n_features
    n_classes = dataset_config.n_classes

    mlp_model_config = MLPModelConfig(
        loss="cross_entropy",
        hidden_dim=hidden_dims,
        use_bias=False,
    )

    full_config = Config(
        dataset=dataset_config,
        model=mlp_model_config,
        training=training_configs[dataset_name],
    )

    mlp_hessian_configs: Dict[str, KFAC] = {
        "kfac": KFAC.setup_with_run_and_build_config(
            full_config=full_config,
            build_config=KFACBuildConfig(
                use_pseudo_targets=True,
            ),
            run_config=KFACRunConfig(
                use_eigenvalue_correction=False,
            ),
        ),
        "ekfac": KFAC.setup_with_run_and_build_config(
            full_config=full_config,
            build_config=KFACBuildConfig(
                use_pseudo_targets=True,
            ),
            run_config=KFACRunConfig(
                use_eigenvalue_correction=True,
            ),
        ),
    }

    results_dict[dataset_name] = compare_approximation_with_true_hessian(
        hessian_approxs=mlp_hessian_configs
    )
    print(f"Completed dataset: {dataset_name}")
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 98.35it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Completed dataset: random_classification_2000_10_5
# 100%|██████████| 100/100 [00:00<00:00, 104.56it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Completed dataset: random_classification_2000_48_5
# 100%|██████████| 100/100 [00:01<00:00, 99.62it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Completed dataset: random_classification_2000_92_5
# 100%|██████████| 100/100 [00:01<00:00, 98.47it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Completed dataset: random_classification_2000_136_5
# 100%|██████████| 100/100 [00:01<00:00, 98.41it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Completed dataset: random_classification_2000_180_5
# 100%|██████████| 100/100 [00:01<00:00, 95.99it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Completed dataset: random_classification_2000_224_5
# 100%|██████████| 100/100 [00:01<00:00, 93.96it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Completed dataset: random_classification_2000_268_5
# 100%|██████████| 100/100 [00:01<00:00, 92.81it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Completed dataset: random_classification_2000_312_5
# 100%|██████████| 100/100 [00:01<00:00, 91.75it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Completed dataset: random_classification_2000_356_5
# 100%|██████████| 100/100 [00:01<00:00, 83.08it/s]
# Computing EKFAC components from scratch.
# Loading EKFAC components from disk.
# Completed dataset: random_classification_2000_400_5

# %%
# Print results
print("Final Results for Multi-Layer MLP Models:")
for dataset_name, result in results_dict.items():
    print(f"Dataset: {dataset_name}")
    for approx_name, metrics in result.items():
        print(f"  Approximation: {approx_name}")
        for metric_name, value in metrics.items():
            print(f"    {metric_name}: {value}")

# Plot results
# Extract data for plotting
datasets = list(results_dict.keys())
parameter_sizes = []
max_elementwise_kfac = []
max_elementwise_ekfac = []
spectral_norm_kfac = []
spectral_norm_ekfac = []
cosine_sim_kfac = []
cosine_sim_ekfac = []
eigenval_l2_kfac = []
eigenval_l2_ekfac = []

for dataset in datasets:
    # Extract n_features and n_classes from dataset name
    parts = dataset.split("_")
    n_features = int(parts[3])
    n_classes = int(parts[4])
    param_size = total_params_dict[
        f"random_classification_{n_samples}_{n_features}_{n_classes}"
    ]
    parameter_sizes.append(param_size)

    # Extract metrics for KFAC and EKFAC
    kfac_metrics = results_dict[dataset]["kfac"]
    ekfac_metrics = results_dict[dataset]["ekfac"]

    max_elementwise_kfac.append(kfac_metrics["max_elementwise"])
    max_elementwise_ekfac.append(ekfac_metrics["max_elementwise"])
    spectral_norm_kfac.append(kfac_metrics["spectral"])
    spectral_norm_ekfac.append(ekfac_metrics["spectral"])
    cosine_sim_kfac.append(kfac_metrics["cosine_similarity"])
    cosine_sim_ekfac.append(ekfac_metrics["cosine_similarity"])
    eigenval_l2_kfac.append(kfac_metrics["eigenvalues_l2_distance"])
    eigenval_l2_ekfac.append(ekfac_metrics["eigenvalues_l2_distance"])
# Out:
# Final Results for Multi-Layer MLP Models:
# Dataset: random_classification_2000_10_5
#   Approximation: kfac
#     relative_frobenius: 0.7510558551216063
#     max_elementwise: 0.20352555811405182
#     spectral: 0.8617598216569802
#     spectral_relative: 0.649361961771229
#     cosine_similarity: 0.6607479891276581
#     eigenvalue_max: 0.7465867012006144
#     eigenvalues_l2_distance: 0.454057637014276
#     trace_distance: 0.0011244188189383358
#     condition_number_log_ratio: 3.9779681232793482
#   Approximation: ekfac
#     relative_frobenius: 0.7271349552014853
#     max_elementwise: 0.20352555811405182
#     spectral: 0.7518998205258217
#     spectral_relative: 0.566579144492107
#     cosine_similarity: 0.6865744873667875
#     eigenvalue_max: 0.46376158885777996
#     eigenvalues_l2_distance: 0.3490881122800776
#     trace_distance: 0.0007449272853864386
#     condition_number_log_ratio: 3.581057932697073
# Dataset: random_classification_2000_48_5
#   Approximation: kfac
#     relative_frobenius: 0.6135699161911723
#     max_elementwise: 0.6471765041351318
#     spectral: 2.683827674050416
#     spectral_relative: 0.5640312253428124
#     cosine_similarity: 0.7897366782155449
#     eigenvalue_max: 1.4824969925090992
#     eigenvalues_l2_distance: 0.26957710452704786
#     trace_distance: 0.004553307471629064
#     condition_number_log_ratio: 4.6129223533383215
#   Approximation: ekfac
#     relative_frobenius: 0.6061898761376532
#     max_elementwise: 0.6471765041351318
#     spectral: 2.7435878407634613
#     spectral_relative: 0.5765903774760713
#     cosine_similarity: 0.7961654156218371
#     eigenvalue_max: 1.6974637664959156
#     eigenvalues_l2_distance: 0.2901887509419528
#     trace_distance: 0.002402349662555902
#     condition_number_log_ratio: 4.680764360021671
# Dataset: random_classification_2000_92_5
#   Approximation: kfac
#     relative_frobenius: 0.44736013189956064
#     max_elementwise: 1.2062294483184814
#     spectral: 4.640394900889511
#     spectral_relative: 0.3815077652601162
#     cosine_similarity: 0.8945347237126812
#     eigenvalue_max: 1.5709544345915525
#     eigenvalues_l2_distance: 0.14325068465804938
#     trace_distance: 0.001835387803019778
#     condition_number_log_ratio: 4.336388783200016
#   Approximation: ekfac
#     relative_frobenius: 0.4477629117006509
#     max_elementwise: 1.2062294483184814
#     spectral: 4.892233104684221
#     spectral_relative: 0.4022125182798268
#     cosine_similarity: 0.8958448536308488
#     eigenvalue_max: 2.0104862047493235
#     eigenvalues_l2_distance: 0.16934650568808773
#     trace_distance: 0.007431437509560293
#     condition_number_log_ratio: 4.392015175564518
# Dataset: random_classification_2000_136_5
#   Approximation: kfac
#     relative_frobenius: 0.4293388304236033
#     max_elementwise: 1.3838289976119995
#     spectral: 7.910120892123545
#     spectral_relative: 0.4870930605858437
#     cosine_similarity: 0.9041781293432328
#     eigenvalue_max: 1.7514373167880422
#     eigenvalues_l2_distance: 0.1007480771657525
#     trace_distance: 0.0030022679313770674
#     condition_number_log_ratio: 5.790094272533159
#   Approximation: ekfac
#     relative_frobenius: 0.41652152132646963
#     max_elementwise: 1.3838289976119995
#     spectral: 6.6792017215535235
#     spectral_relative: 0.41129495404568195
#     cosine_similarity: 0.9091468003290203
#     eigenvalue_max: 1.9296272714729188
#     eigenvalues_l2_distance: 0.1053061069654462
#     trace_distance: 0.0015718335482106912
#     condition_number_log_ratio: 5.918011085429887
# Dataset: random_classification_2000_180_5
#   Approximation: kfac
#     relative_frobenius: 0.3475992332046452
#     max_elementwise: 1.3555651903152466
#     spectral: 5.447532392385969
#     spectral_relative: 0.261644263307094
#     cosine_similarity: 0.9383792923181012
#     eigenvalue_max: 2.0032543146916844
#     eigenvalues_l2_distance: 0.08868795275705403
#     trace_distance: 0.005752951794366042
#     condition_number_log_ratio: 4.606052509269942
#   Approximation: ekfac
#     relative_frobenius: 0.34350937219265765
#     max_elementwise: 1.3555651903152466
#     spectral: 5.392813793027953
#     spectral_relative: 0.25901613618696256
#     cosine_similarity: 0.9393464505930297
#     eigenvalue_max: 1.935437974364227
#     eigenvalues_l2_distance: 0.10879504692240088
#     trace_distance: 0.0015798607056339582
#     condition_number_log_ratio: 4.524071804008711
# Dataset: random_classification_2000_224_5
#   Approximation: kfac
#     relative_frobenius: 0.38686264103368256
#     max_elementwise: 1.8433276452124119
#     spectral: 7.100921504999416
#     spectral_relative: 0.2875957412385021
#     cosine_similarity: 0.9285078823116881
#     eigenvalue_max: 1.9813227127341975
#     eigenvalues_l2_distance: 0.07392962779066935
#     trace_distance: 0.010223327077056239
#     condition_number_log_ratio: 5.510625253015412
#   Approximation: ekfac
#     relative_frobenius: 0.4203771567597174
#     max_elementwise: 4.0271950997412205
#     spectral: 9.920430107981987
#     spectral_relative: 0.40178918303788064
#     cosine_similarity: 0.9252386132541202
#     eigenvalue_max: 7.0847536116124274
#     eigenvalues_l2_distance: 0.1789597315966705
#     trace_distance: 0.010244340044456348
#     condition_number_log_ratio: 5.279923806482209
# Dataset: random_classification_2000_268_5
#   Approximation: kfac
#     relative_frobenius: 0.3128486871199056
#     max_elementwise: 4.266140662133694
#     spectral: 10.48321525868618
#     spectral_relative: 0.27007253288196353
#     cosine_similarity: 0.9500901376185639
#     eigenvalue_max: 3.4747471996863055
#     eigenvalues_l2_distance: 0.08682756570581494
#     trace_distance: 0.0014013854168125593
#     condition_number_log_ratio: 3.923053486404516
#   Approximation: ekfac
#     relative_frobenius: 0.3195916798927628
#     max_elementwise: 5.263222418725491
#     spectral: 11.316251390164998
#     spectral_relative: 0.29153352289876805
#     cosine_similarity: 0.9496639997240369
#     eigenvalue_max: 4.809809226663845
#     eigenvalues_l2_distance: 0.12386009399609432
#     trace_distance: 0.004035024716097949
#     condition_number_log_ratio: 3.9714581800080317
# Dataset: random_classification_2000_312_5
#   Approximation: kfac
#     relative_frobenius: 0.2970628679105601
#     max_elementwise: 2.6265564411878586
#     spectral: 9.265623897138925
#     spectral_relative: 0.2432938477587598
#     cosine_similarity: 0.9549737209872489
#     eigenvalue_max: 2.513342750762547
#     eigenvalues_l2_distance: 0.08771748800398516
#     trace_distance: 0.003071891794094877
#     condition_number_log_ratio: 6.202715582825126
#   Approximation: ekfac
#     relative_frobenius: 0.29619939082522456
#     max_elementwise: 2.8008116111159325
#     spectral: 9.462478453446453
#     spectral_relative: 0.24846279298949497
#     cosine_similarity: 0.9559641411236993
#     eigenvalue_max: 4.285040748809422
#     eigenvalues_l2_distance: 0.10739437478963351
#     trace_distance: 0.004130426705822185
#     condition_number_log_ratio: 6.253850645996513
# Dataset: random_classification_2000_356_5
#   Approximation: kfac
#     relative_frobenius: 0.3134186176051263
#     max_elementwise: 2.324082300066948
#     spectral: 10.930523470240813
#     spectral_relative: 0.26602921610440045
#     cosine_similarity: 0.9496836125360214
#     eigenvalue_max: 3.5366106616975372
#     eigenvalues_l2_distance: 0.094155203195169
#     trace_distance: 0.005458038197087311
#     condition_number_log_ratio: 6.752686163704123
#   Approximation: ekfac
#     relative_frobenius: 0.32954743554575777
#     max_elementwise: 4.924647230654955
#     spectral: 10.050077805543324
#     spectral_relative: 0.24460075747296492
#     cosine_similarity: 0.9498621303537813
#     eigenvalue_max: 3.5985490733020313
#     eigenvalues_l2_distance: 0.08660746466774163
#     trace_distance: 0.011615770181738342
#     condition_number_log_ratio: 6.623563906471457
# Dataset: random_classification_2000_400_5
#   Approximation: kfac
#     relative_frobenius: 0.3095609609402767
#     max_elementwise: 2.75774222612381
#     spectral: 8.716291468097744
#     spectral_relative: 0.21926606127540646
#     cosine_similarity: 0.9519623683285771
#     eigenvalue_max: 2.3372504853332003
#     eigenvalues_l2_distance: 0.0776034452182073
#     trace_distance: 0.004376671470393158
#     condition_number_log_ratio: 5.136126154608068
#   Approximation: ekfac
#     relative_frobenius: 0.30785904908636164
#     max_elementwise: 3.483885109424591
#     spectral: 8.677683812183604
#     spectral_relative: 0.2182948513659681
#     cosine_similarity: 0.9523780978215449
#     eigenvalue_max: 2.08453389661787
#     eigenvalues_l2_distance: 0.07432097015817465
#     trace_distance: 0.00516499106395144
#     condition_number_log_ratio: 5.169224852270421

# %%
# Create subplot with 4 plots side by side
fig, axes = plt.subplots(1, 4, figsize=(20, 5))
# Plot 1: Max Elementwise
axes[0].plot(parameter_sizes, max_elementwise_kfac, "o-", label="KFAC", color="orange")
axes[0].plot(parameter_sizes, max_elementwise_ekfac, "s-", label="EKFAC", color="green")
axes[0].set_xlabel("Parameter Size")
axes[0].set_ylabel("Max Elementwise Difference")
axes[0].set_title("Max Elementwise Difference")
axes[0].legend()
axes[0].grid(True)

# Plot 2: Spectral Norm
axes[1].plot(parameter_sizes, spectral_norm_kfac, "o-", label="KFAC", color="orange")
axes[1].plot(parameter_sizes, spectral_norm_ekfac, "s-", label="EKFAC", color="green")
axes[1].set_xlabel("Parameter Size")
axes[1].set_ylabel("Spectral Norm")
axes[1].set_title("Spectral Norm")
axes[1].legend()
axes[1].grid(True)
# Plot 3: Cosine Similarity
axes[2].plot(parameter_sizes, cosine_sim_kfac, "o-", label="KFAC", color="orange")
axes[2].plot(parameter_sizes, cosine_sim_ekfac, "s-", label="EKFAC", color="green")
axes[2].set_xlabel("Parameter Size")
axes[2].set_ylabel("Cosine Similarity")
axes[2].set_title("Cosine Similarity")
axes[2].legend()
axes[2].grid(True)
# Plot 4: Eigenvalues L2 Distance
axes[3].plot(parameter_sizes, eigenval_l2_kfac, "o-", label="KFAC", color="orange")
axes[3].plot(parameter_sizes, eigenval_l2_ekfac, "s-", label="EKFAC", color="green")
axes[3].set_xlabel("Parameter Size ")
axes[3].set_ylabel("Eigenvalues L2 Distance")
axes[3].set_title("Eigenvalues L2 Distance")
axes[3].legend()
axes[3].grid(True)

# %% [markdown]
# ### Comparison of IHVP for Hessian vs. KFAC vs. EKFAC
